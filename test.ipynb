# %%
print('hello world')
# Out:
# hello world

# %%
from crewai import Agent, Task, Crew, LLM
from crewai_tools import SerperDevTool
from litellm import completion
from env import (AWS_ACCESS_KEY_ID, AWS_SECRET_ACCESS_KEY, OPENAI_API_KEY)

# %%
import os
os.environ["AWS_ACCESS_KEY_ID"] = AWS_ACCESS_KEY_ID
os.environ["AWS_SECRET_ACCESS_KEY"] = AWS_SECRET_ACCESS_KEY
os.environ["AWS_REGION_NAME"] = "us-east-2"
os.environ["OPENAI_API_KEY"] = ""
#os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain_aws import BedrockLLM

custom_llm = BedrockLLM(
    credentials_profile_name="sharks",
    provider="bedrock",
    model_id="amazon.titan-tg1-large",
    model_kwargs={"temperature": 1},
    streaming=False,
)

custom_llm.invoke(input="What is the recipe of mayonnaise?")
# Out:
# '\nHere is the recipe of mayonnaise:\n\nIngredients:\n- 1 egg yolk\n- 1 tablespoon Dijon mustard\n- 1 tablespoon white wine vinegar\n- 1 teaspoon salt\n- 1/2 teaspoon ground black pepper\n- 1/2 cup vegetable oil\n\nInstructions:\n1. In a mixing bowl, combine the egg yolk, mustard, vinegar, salt, and pepper. Whisk until well combined.\n2. Slowly drizzle the vegetable oil into the mixture, whisking continuously, until it is fully incorporated and the mixture becomes thick and creamy.'

# %%
social_media_analyst = Agent(
 role='Social Media Analyst',
 goal='Review companies from a social media perspective in order to understand public sentiment and social media trends. You specifically want to understand how the company is seen on Twitter, Facebook, and other social media platforms.',
 backstory="You work at a leading social media marketing company.",
 verbose=True,
 allow_delegation=False,
 custom_llm=custom_llm,
#tool=[SerperDevTool()] # Tool for online searching
)

# %%
researcher = Agent(
 role='Senior FINRA Analyst',
 goal='Uncover new information about companies from a financial perspective to be able to make investment decisions for stakeholders. You want to identify good investment opportunities and recommend potential strategies to benefit from the companies current position.',
 backstory="You work at a leading investment think tank…",
 verbose=True,
 allow_delegation=False,
 custom_llm=custom_llm,
#tool=[SerperDevTool()] # Tool for online searching
)
# Define the Task
task1 = Task(
 description="Conduct a comprehensive analysis of the following topic: {topic}",
 expected_output="Full analysis report in bullet points",
 agent=researcher
)
task2 = Task(
 description="Conduct a comprehensive social media and public sentiment analysis of the following topic: {topic}",
 expected_output="Full market report in bullet points",
 agent=social_media_analyst
)
crew = Crew(
 agents=[researcher, social_media_analyst],
 tasks=[task1, task2],
 verbose=True,
)
# Out:
# 2024-11-03 11:41:54,131 - 8117181504 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed

# %%
result = crew.kickoff(inputs={"topic":"Recent News concerning the company NVIDIA"})
# Out:
# # Agent: Senior FINRA Analyst
# ## Task: Conduct a comprehensive analysis of the following topic: Recent News concerning the company NVIDIA
# 2024-11-03 11:41:58,676 - 8117181504 - llm.py-llm:161 - ERROR: LiteLLM call failed: litellm.APIError: APIError: OpenAIException - Connection error.
# # Agent: Senior FINRA Analyst
# ## Task: Conduct a comprehensive analysis of the following topic: Recent News concerning the company NVIDIA
# 2024-11-03 11:42:02,125 - 8117181504 - llm.py-llm:161 - ERROR: LiteLLM call failed: litellm.APIError: APIError: OpenAIException - Connection error.
# # Agent: Senior FINRA Analyst
# ## Task: Conduct a comprehensive analysis of the following topic: Recent News concerning the company NVIDIA
# 2024-11-03 11:42:06,867 - 8117181504 - llm.py-llm:161 - ERROR: LiteLLM call failed: litellm.APIError: APIError: OpenAIException - Connection error.
# ---------------------------------------------------------------------------
# ...
