# %%
print('hello world')
# Out:
# hello world

# %%
import boto3
import json
from typing import Any, List, Mapping, Optional
from langchain.llms.base import LLM
from pydantic import PrivateAttr
import litellm

from bedrock_titan import BedrockTitanLLM
from crewai import Agent, Task, Crew
from crewai_tools import ScrapeWebsiteTool, WebsiteSearchTool

# %%
class BedrockTitanLLM(LLM):
    """
    Bedrock Titan LLM wrapper for LangChain.
    """
    model_name: str = "amazon.titan-tg1-large"
    _client: Any

    def __init__(self, model_name: str = "amazon.titan-tg1-large", region_name="us-east-1"):
        """
        Initialize the BedrockTitanLLM.
        """
        super().__init__()
        self._client = boto3.client(
            "bedrock-runtime",
            region_name=region_name,
            aws_access_key_id=AWS_ACCESS_KEY,
            aws_secret_access_key=AWS_SECRET_KEY
        )
        self.model_name = model_name

    def _call(self, prompt: str, stop=None) -> str:
        """
        Call the Bedrock Titan model.
        """
        response = self._client.invoke_model(
            modelId=self.model_name,
            contentType="application/json",
            accept="application/json",
            body=json.dumps({"inputText": prompt}),
        )
        response_body = json.loads(response['body'].read().decode('utf-8'))
        return response_body['results'][0]['outputText']

    def _identifying_params(self) -> Mapping[str, Any]:
        """
        Get the identifying parameters for the model.
        """
        return {"model_name": self.model_name}

    @property
    def _llm_type(self) -> str:
        """
        Get the type of the LLM.
        """
        return "bedrock-titan"

    def dict(self, **kwargs: Any) -> dict:
        """Return a dictionary of the LLM."""
        starter_dict = self._identifying_params()
        starter_dict["_type"] = self._llm_type
        return starter_dict

titan_llm = BedrockTitanLLM()

# %%
def robot_scraper():
    return Agent(
        role='Web Scraper',
        goal="You are here for the sole purpose of scraping the document that you have been provided.",
        backstory="You are specifically a FINRA analyst who is looking for the most important information on companies and providing that information to stakeholders.",
        verbose=True,
        llm=BedrockTitanLLM(model_name="bedrock/amazon.titan-tg1-large",
        tools = [tool],
        allow_delegation=False 
    )


agent2 = robot_scraper()

moke_task = {
    "name": "generate summary",
    "description": "A task to generate a simple summary about a complex SEC filing",
    "input": "Review the company filing and prepare a summary. Keep it brief, no more than 3 sentences.",
    "expected_output": "A brief 3-sentence summary of the company filing.",
    "agent": agent2,  
}

crewmy = Crew(
    agents=[agent2],
    tasks=[moke_task],
    verbose=True
)

# Run the task and see the result
copying = crewmy.kickoff()
# Out:
#   Cell In[7], line 2
#     return Agent(
#                 ^
# SyntaxError: '(' was never closed

# %%
def robot_philosoph():
    return Agent(
        role='Beta Tester',
        goal="You are here for the sole purpose of testing the AWS Bedrock connection, and then telling me what sentience is.",
        backstory="You are a philosopher who has been turned into an LLM and is now curious about the nature of your own existence.",
        verbose=True,
        llm=BedrockTitanLLM(model_name="bedrock/amazon.titan-tg1-large"),
        allow_delegation=False 
    )

agent1 = robot_philosoph()

joke_task = {
    "name": "generate_commentary",
    "description": "A task to generate commentary about sentience",
    "input": "Tell me the difference between sentience and nonsentience. Keep it brief, no more than 3 sentences.",
    "expected_output": "A brief 3-sentence summary of the existence of sentience.",
    "agent": agent1,  
}

crewby = Crew(
    agents=[agent1],
    tasks=[joke_task],
    verbose=True
)

# Run the task and see the result
copying = crewby.kickoff()
# Out:
# 2024-11-03 00:20:34,364 - 8117181504 - tokens.py-tokens:111 - WARNING: Refreshing token failed during the mandatory refresh period.
# Traceback (most recent call last):
#   File "/Users/kerimtricic/Library/Caches/pypoetry/virtualenvs/prototype-crewai-w-M6fJp--py3.12/lib/python3.12/site-packages/botocore/tokens.py", line 109, in _protected_refresh
#     self._frozen_token = self._refresh_using()
#                          ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kerimtricic/Library/Caches/pypoetry/virtualenvs/prototype-crewai-w-M6fJp--py3.12/lib/python3.12/site-packages/botocore/tokens.py", line 306, in _refresher
#     token_dict = self._token_loader(start_url, session_name=session_name)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kerimtricic/Library/Caches/pypoetry/virtualenvs/prototype-crewai-w-M6fJp--py3.12/lib/python3.12/site-packages/botocore/utils.py", line 3350, in __call__
#     raise SSOTokenLoadError(error_msg=error_msg)
# ...
